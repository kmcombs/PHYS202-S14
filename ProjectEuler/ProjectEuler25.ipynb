# %% [markdown]
# # Project Euler

# %% [markdown]
# ### Problem 25

# %% [markdown]
# The Fibonacci sequence is defined by the recurrence relation:
#
#
# Fn = Fn−1 + Fn−2, where F1 = 1 and F2 = 1.
#
# Hence the first 12 terms will be:
#
# F1 = 1
# F2 = 1
# F3 = 2
# F4 = 3
# F5 = 5
# F6 = 8
# F7 = 13
# F8 = 21
# F9 = 34
# F10 = 55
# F11 = 89
# F12 = 144
#
# The 12th term, F12, is the first term to contain three digits.
#
# What is the first term in the Fibonacci sequence to contain 1000 digits?

# %%
def fib(n):
    if n <= 2:
        return 1
    else:
        return fib(n-2) + fib(n-1)

n = 0
while len(str(fib(n))) <= 3:
    n += 1
    if len(str(fib(n))) == 3:
        print n
        break
# Out:
# 12

# %%
def fib(n):
    if n <= 2:
        return 1
    else:
        return fib(n-2) + fib(n-1)

n = 0
while len(str(fib(n))) <= 1000:
    n += 1
    if len(str(fib(n))) == 1000:
        print n
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-aaf45e975116> in <module>()
#       6
#       7 n = 0
# ----> 8 while len(str(fib(n))) <= 1000:
#       9     n += 1
#      10     if len(str(fib(n))) == 1000:
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-2) + fib(n-1)
#       6
#       7 n = 0
#
# <ipython-input-21-aaf45e975116> in fib(n)
# ----> 1 def fib(n):
#       2     if n <= 2:
#       3         return 1
#       4     else:
#       5         return fib(n-2) + fib(n-1)
#
# KeyboardInterrupt:
