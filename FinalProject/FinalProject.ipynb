# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pic1 = Image.open('pic1.jpg')
plt.imshow(pic1)

# %%
class Blob():
    def __init__(blob):
        #Constructs and empty blob
        blob.pixels = []
    def add(blob, i , j):
        #add pixels i and j to blob
        blob.pixels.append((i,j))
    def mass(blob):
        #return number of pixels added
        mass = len(blob.pixels)
        return mass
    def centerOfMass(blob):
        #return (x,y) location of blob's center of mass
        #format with 4 digits to the right of the decimal point
        x = 0
        y = 0
        for loc in range(0, len(blob.pixels)):
            x += blob.pixels[loc][0]
            y += blob.pixels[loc][1]
        xcm = float(x)/float(len(blob.pixels))
        ycm = float(y)/float(len(blob.pixels))
        return ["%.4f" %xcm, "%.4f" %ycm]

# %%
def countBeads(P, blob_m):
    '''return the number of beads with >= P pixels'''
    i = 0
    for i in blob_m:
        if i >= P:
            i+= 1
    return i

def getBeads(P, blob_m, blob_cm):
    '''return all beads with >= P pixels'''
    bead_m = []
    bead_cm = []
    for i in range(len(blob_m)):
        if blob_m[i] >= P:
            bead_m.append(blob_m[i])
            bead_cm.append(blob_cm[i])
    return bead_m, bead_cm

def BlobFinder(pic, tau, P):
    """scan the image top to bottom and left to right using a nested loop.
    when black pixel is found, increment the count, then call the fill
    function to fill in all the pixels connected to that one."""
    blob1 = Blob()
    blob_cm = []
    blob_m = []
    BLACK = (0, 0, 0)
    WHITE = (255, 255, 255)
    RED = (255, 0, 0)
    xsize, ysize = pic.size
    temp = pic.load()
    for x in range(xsize):
        for y in range(ysize):
            r,g,b = temp[x,y]
            if r+g+b >= tau: 
                temp[x,y] = BLACK
            else:
                temp[x,y] = WHITE
    for x in range(xsize):
        for y in range(ysize):
            if temp[x,y] == BLACK:
                blob1.__init__()
                """keep a list of pixels that need to be looked at, 
                but haven't yet been filled in - a list of the (x,y) 
                coordinates of pixels that are neighbors of ones we have 
                already examined.  Keep looping until there's nothing 
                left in this list"""
                queue = [(x,y)]
                while queue:
                    x,y,queue = queue[0][0], queue[0][1], queue[1:]
                    if temp[x,y] == BLACK:
                        temp[x,y] = RED
                        blob1.add(x,y)
                        if x > 0:
                            queue.append((x-1,y))
                        if x < (xsize-1):
                            queue.append((x+1,y))
                        if y > 0:
                            queue.append((x, y-1))
                        if y < (ysize-1):
                            queue.append((x, y+1))
                blob_cm.append(blob1.centerOfMass())
                blob_m.append(blob1.mass())
    i = countBeads(P, blob_m)
    bead_m, bead_cm = getBeads(P, blob_m, blob_cm)
    return bead_m, bead_cm

# %%
pic1 = Image.open('pic3.jpg')
BlobFinder(pic1, 645., 25)
# Out:
# ([29, 40, 36, 25, 43, 29, 33],
#  [['96.3103', '93.2414'],
#   ['185.6500', '83.5250'],
#   ['192.5278', '91.7500'],
#   ['189.8400', '295.0800'],
#   ['195.6279', '82.1860'],
#   ['267.5172', '4.7931'],
#   ['355.0000', '302.0909']])

# %%
filenames = []
for i in range(0, 200):
    i = str(i)
    if len(i) == 1:
        filename = 'frame0000' + i + '.jpg'
        filenames.append(filename)
    if len(i) == 2:
        filename = 'frame000' + i + '.jpg'
        filenames.append(filename)
    if len(i) == 3:
        filename = 'frame00' + i + '.jpg'
        filenames.append(filename)

# %%
pictures = []
for i in range(1,5):
    i = str(i)
    filename = 'pic' + i + '.jpg'
    pictures.append(filename)

# %%
def Particle_tracking(P, tau, p, pictures):
    i = 0
    r = []
    while i <= len(pictures)-2:
        pic1 = Image.open(pictures[i])
        pic2 = Image.open(pictures[i+1])
        bead_m1, bead_cm1 = BlobFinder(pic1, tau, P)
        bead_m2, bead_cm2 = BlobFinder(pic2, tau, P)
        for blob1 in bead_cm1:
            xi = float(blob1[0])
            yi = float(blob1[1])
            dist = []
            for blob2 in bead_cm2:
                xf = float(blob2[0])
                yf = float(blob2[1])
                distance = ((xf - xi)**2 + (yf - yi)**2) ** 0.5
                if distance <= p and distance > 0:
                    dist.append(distance)
            if len(dist) > 0:
                r.append(min(dist))
        i += 1
    return r

# %%
r = Particle_tracking(29, 645., 13., pictures)
sigma = 0
for i in r:
    l = i*(0.175e-6)
    sigma += l**2
D = sigma/(2*int(len(r)))
print D
# Out:
# 4.35659431251e-13

# %%
k = (6.* D * np.pi * (9.135e-4)*(0.5e-6))/297.
print k
# Out:
# 1.26290403247e-23

# %%
Na = 8.31457/k
print Na
# Out:
# 6.58369106934e+23
